# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data1 = pd.read_excel('Public-Dataset-Daily-County-Cases-5-18-Years.xlsx')
data1.head(10)
# Out:
#         DATE    COUNTY  TOTAL_CASES  NEW_CASES
# 0 2022-02-19  Anderson         4033          1
# 1 2022-02-19   Bedford         2490          0
# 2 2022-02-19    Benton          677          0
# 3 2022-02-19   Bledsoe          620          0
# 4 2022-02-19    Blount         5433          0
# 5 2022-02-19   Bradley         5166          0
# 6 2022-02-19  Campbell         1916          3
# 7 2022-02-19    Cannon          580          0
# 8 2022-02-19   Carroll         1365          3
# 9 2022-02-19    Carter         2521          0

# %%
data_max= pd.DataFrame(data1.groupby(by='COUNTY').max())
data_max.reset_index(inplace=True)
data_max.head()
# Out:
#      COUNTY       DATE  TOTAL_CASES  NEW_CASES
# 0  Anderson 2022-02-19         4033        120
# 1   Bedford 2022-02-19         2490         86
# 2    Benton 2022-02-19          677         35
# 3   Bledsoe 2022-02-19          620         32
# 4    Blount 2022-02-19         5433        204

# %%
plt.style.use('fivethirtyeight')
fig, ax = plt.subplots(figsize=(26, 50))
sns.barplot(y=data_max.COUNTY,x=data_max.TOTAL_CASES)
for i in ax.patches:
    plt.text(i.get_width()+0.7, i.get_y()+0.6,
             str(round((i.get_width()), 2)),
             fontsize=20, fontweight='bold',
             color='blue',alpha=0.5)
# Add Plot Title
ax.set_title('TN 5-18Years Total Cases By County',
             loc='CENTER',color="blue" )
  
# Add Text watermark
fig.text(0.2, 0.0, 'Osamah Neamah', fontsize=14,
         color='green', ha='left', va='bottom',
         alpha=0.6)
  
# Show Plot
plt.show()

# %%
data2= data_max.nlargest(10,['TOTAL_CASES'])
plt.style.use('fivethirtyeight')
fig, ax = plt.subplots(figsize=(26, 13))
sns.barplot(y=data2.COUNTY,x=data2.TOTAL_CASES)
for i in ax.patches:
    plt.text(i.get_width()+0.7, i.get_y()+0.4,
             str(round((i.get_width()), 2)),
             fontsize=20, fontweight='bold',
             color='blue',alpha=0.5)
# Add Plot Title
ax.set_title('TN TOP 10 CONUTIES 5-18 Years',
             loc='CENTER',color="blue" )
  
# Add Text watermark
fig.text(0.2, 0.0, 'Osamah Neamah', fontsize=14,
         color='green', ha='left', va='bottom',
         alpha=0.6)
  
# Show Plot
plt.show()
